# %%
import pandas as pd

import pyEX as p

c = p.Client(api_token='Tpk_8b60e573f58844adb8026f0e6db6fd2b', version='sandbox')

spydf = c.chartDF('TWTR', timeframe='max')
spydf.head()
# Out:
#             close   high     low   open symbol     volume                 id  \
# date
# 2022-05-13  40.75  43.00  40.220  40.60   TWTR  106050565  COIP_SSARTLHICERI
# 2022-05-12  45.17  49.13  43.550  46.49   TWTR   38395225  TILOR_IRHCPSIASEC
# 2022-05-11  47.53  49.22  47.100  49.06   TWTR   25082939  AISPHRLSITICORC_E
# 2022-05-10  48.07  50.69  48.000  49.82   TWTR   24850340  CIIHRRAS_CEPLOTIS
# 2022-05-09  48.68  50.10  48.475  50.10   TWTR   39150298  PSICE_AIRTSOCHRIL
#
#              key subkey                       updated  ...    uLow    uVolume  \
# date                                                   ...
# 2022-05-13  RTWT        2023-07-02 04:10:13.166000128  ...  40.980  105267990
# 2022-05-12  TWRT        2023-03-03 07:42:11.801999872  ...  43.840   38169621
# 2022-05-11  TWRT        2023-02-24 04:34:09.748000000  ...  46.400   25173837
# 2022-05-10  RTTW        2023-03-20 13:39:51.905999872  ...  48.000   24746197
# 2022-05-09  WTRT        2024-06-28 18:34:19.520999936  ...  49.974   38335198
#
#             fOpen  fClose  fHigh    fLow    fVolume       label    change  \
# date
# 2022-05-13  41.10   42.48  43.00  41.880  104476191  May 13, 22  0.000000
# 2022-05-12  45.39   47.12  47.96  44.040   39520013  May 12, 22  4.459023
# 2022-05-11  48.22   47.49  48.18  47.500   25039651  May 11, 22  1.016547
# 2022-05-10  49.02   48.13  49.82  46.600   24619054  May 10, 22  1.221595
# 2022-05-09  51.10   48.85  49.96  49.872   37787767   May 9, 22  0.724113
#
#             changePercent
# date
# 2022-05-13         0.0000
# 2022-05-12         0.1115
# 2022-05-11         0.0226
# 2022-05-10         0.0258
# 2022-05-09         0.0154
#
# [5 rows x 25 columns]

# %%
# !pip install pyEX
# Out:
# Requirement already satisfied: pyEX in ./hft/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: ipython>=7.2.0 in ./hft/lib/python3.8/site-packages (from pyEX) (8.2.0)
# Requirement already satisfied: Pillow>=5.3.0 in ./hft/lib/python3.8/site-packages (from pyEX) (9.1.0)
# Requirement already satisfied: requests>=2.21.0 in ./hft/lib/python3.8/site-packages (from pyEX) (2.27.1)
# Requirement already satisfied: socketIO-client-nexus>=0.7.6 in ./hft/lib/python3.8/site-packages (from pyEX) (0.7.6)
# Requirement already satisfied: six in ./hft/lib/python3.8/site-packages (from pyEX) (1.16.0)
# Requirement already satisfied: pandas>=0.22 in ./hft/lib/python3.8/site-packages (from pyEX) (1.4.1)
# Requirement already satisfied: pytz>=2019.1 in ./hft/lib/python3.8/site-packages (from pyEX) (2022.1)
# Requirement already satisfied: sseclient>=0.0.22 in ./hft/lib/python3.8/site-packages (from pyEX) (0.0.27)
# Requirement already satisfied: deprecation>=2.0.6 in ./hft/lib/python3.8/site-packages (from pyEX) (2.1.0)
# Requirement already satisfied: temporal-cache>=0.1.1 in ./hft/lib/python3.8/site-packages (from pyEX) (0.1.4)
# Requirement already satisfied: packaging in ./hft/lib/python3.8/site-packages (from deprecation>=2.0.6->pyEX) (21.3)
# Requirement already satisfied: pexpect>4.3 in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (4.8.0)
# Requirement already satisfied: pickleshare in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (0.7.5)
# Requirement already satisfied: matplotlib-inline in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (0.1.3)
# Requirement already satisfied: stack-data in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (61.0.0)
# Requirement already satisfied: traitlets>=5 in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (5.1.1)
# Requirement already satisfied: appnope in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (0.1.2)
# Requirement already satisfied: backcall in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (2.11.2)
# Requirement already satisfied: decorator in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./hft/lib/python3.8/site-packages (from ipython>=7.2.0->pyEX) (3.0.28)
# Requirement already satisfied: numpy>=1.18.5 in ./hft/lib/python3.8/site-packages (from pandas>=0.22->pyEX) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./hft/lib/python3.8/site-packages (from pandas>=0.22->pyEX) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./hft/lib/python3.8/site-packages (from requests>=2.21.0->pyEX) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in ./hft/lib/python3.8/site-packages (from requests>=2.21.0->pyEX) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./hft/lib/python3.8/site-packages (from requests>=2.21.0->pyEX) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in ./hft/lib/python3.8/site-packages (from requests>=2.21.0->pyEX) (3.3)
# Requirement already satisfied: websocket-client in ./hft/lib/python3.8/site-packages (from socketIO-client-nexus>=0.7.6->pyEX) (1.3.1)
# Requirement already satisfied: tzlocal>=2.0.0 in ./hft/lib/python3.8/site-packages (from temporal-cache>=0.1.1->pyEX) (4.2)
# Requirement already satisfied: frozendict>=1.2 in ./hft/lib/python3.8/site-packages (from temporal-cache>=0.1.1->pyEX) (2.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./hft/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.2.0->pyEX) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./hft/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.2.0->pyEX) (0.7.0)
# Requirement already satisfied: wcwidth in ./hft/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.2.0->pyEX) (0.2.5)
# Requirement already satisfied: backports.zoneinfo in ./hft/lib/python3.8/site-packages (from tzlocal>=2.0.0->temporal-cache>=0.1.1->pyEX) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in ./hft/lib/python3.8/site-packages (from tzlocal>=2.0.0->temporal-cache>=0.1.1->pyEX) (0.1.0.post0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./hft/lib/python3.8/site-packages (from packaging->deprecation>=2.0.6->pyEX) (3.0.7)
# Requirement already satisfied: pure-eval in ./hft/lib/python3.8/site-packages (from stack-data->ipython>=7.2.0->pyEX) (0.2.2)
# Requirement already satisfied: asttokens in ./hft/lib/python3.8/site-packages (from stack-data->ipython>=7.2.0->pyEX) (2.0.5)
# Requirement already satisfied: executing in ./hft/lib/python3.8/site-packages (from stack-data->ipython>=7.2.0->pyEX) (0.8.3)
# Requirement already satisfied: tzdata in ./hft/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal>=2.0.0->temporal-cache>=0.1.1->pyEX) (2022.1)
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the '/Users/riyamanchanda/hft/hft/bin/python -m pip install --upgrade pip' command.

# %%
spydf = spydf.reindex(index=spydf.index[::-1])
spydf.reset_index(level=0, inplace=True)

# %%
spydf['date'] = pd.to_datetime(spydf['date'])

# %%
spydf['ma_20'] = spydf['close'].rolling(20).mean()
spydf['std'] = spydf['close'].rolling(20).std()

spydf['upper_bollinger'] = spydf['ma_20'] + (2 * spydf['std'])
spydf['lower_bollinger'] = spydf['ma_20'] - (2 * spydf['std'])

# %%
def gain(value):
    if value < 0:
        return 0
    else:
        return value

# %%
def loss(value):
    if value > 0:
        return 0
    else:
        return abs(value)

# %%
period = 6

spydf['delta'] = spydf['close'].diff()

spydf['gain'] = spydf['delta'].apply(lambda x:gain(x))
spydf['loss'] = spydf['delta'].apply(lambda x:loss(x))

spydf['ema_gain'] = spydf['gain'].ewm(period).mean()
spydf['ema_loss'] = spydf['loss'].ewm(period).mean()

spydf['rs'] = spydf['ema_gain']/spydf['ema_loss']
spydf['rsi'] = spydf['rs'].apply(lambda x: 100 - (100/(x+1)))

# %%
import numpy as np

spydf['signal'] = np.where(
    (spydf['rsi'] < 30) &
    (spydf['close'] < spydf['lower_bollinger']), 1, np.nan)

spydf['signal'] = np.where(
    (spydf['rsi'] > 70) &
    (spydf['close'] > spydf['upper_bollinger']), -1, spydf['signal'])

spydf['signal'] = spydf['signal'].shift()
spydf['signal'] = spydf['signal'].fillna(0)

# %%
import test as tst

tst.backtest_dataframe(spydf)
# Out:
# Buying at 55.57 on 2014-02-07 00:00:00
# Selling at 37.6 on 2014-06-13 00:00:00
# Buying at 44.04 on 2014-10-29 00:00:00
# Selling at 48.29 on 2015-02-09 00:00:00
# Buying at 39.2 on 2015-04-29 00:00:00
# Selling at 37.35 on 2015-07-15 00:00:00
# Buying at 31.5 on 2015-07-30 00:00:00
# Selling at 32.18 on 2015-10-09 00:00:00
# Buying at 22.86 on 2015-12-22 00:00:00
# Selling at 15.31 on 2016-05-31 00:00:00
# Buying at 16.95 on 2016-07-28 00:00:00
# Selling at 20.9 on 2016-08-16 00:00:00
# Buying at 16.6 on 2016-12-23 00:00:00
# Selling at 17.71 on 2017-02-03 00:00:00
# Buying at 14.58 on 2017-04-10 00:00:00
# Selling at 17.24 on 2017-04-27 00:00:00
# Buying at 16.71 on 2017-08-01 00:00:00
# Selling at 18.9 on 2017-09-13 00:00:00
# Buying at 24.42 on 2018-01-26 00:00:00
# Selling at 27.65 on 2018-02-01 00:00:00
# Buying at 29.6 on 2018-03-28 00:00:00
# Selling at 33.5 on 2018-05-15 00:00:00
# Buying at 32.54 on 2018-07-30 00:00:00
# Selling at 33.23 on 2018-10-29 00:00:00
# Buying at 27.98 on 2018-12-21 00:00:00
# Selling at 36.04 on 2019-04-04 00:00:00
# Buying at 37.6 on 2019-06-04 00:00:00
# Selling at 39.21 on 2019-07-16 00:00:00
# Buying at 40.0 on 2019-10-03 00:00:00
# Selling at 32.6 on 2019-12-24 00:00:00
# Buying at 30.73 on 2020-03-13 00:00:00
# Selling at 33.04 on 2020-05-22 00:00:00
# Buying at 30.54 on 2020-06-29 00:00:00
# Selling at 43.67 on 2020-09-03 00:00:00
# Buying at 47.27 on 2021-01-12 00:00:00
# Selling at 57.17 on 2021-02-05 00:00:00
# Buying at 57.29 on 2021-05-03 00:00:00
# Selling at 65.57 on 2021-06-22 00:00:00
# Buying at 64.84 on 2021-08-16 00:00:00
# Selling at 69.53 on 2021-09-24 00:00:00
# Buying at 55.98 on 2021-10-28 00:00:00
# Selling at 39.51 on 2022-03-18 00:00:00
# Buying at 40.75 on 2022-05-13 00:00:00
#
# Evaluation Metrics:
# -----------------------------------
# Number of Trades: 21
# Number of Gains: 16
# Number of Losses: 5
# Total Returns: 96.34%
# Win Rate: 76.19%
# Average Gain: 14.24%
# Average Loss: -23.6%
# Max Return: 42.99%
# Max Loss: -33.03%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.xticks(rotation=45)

plt.plot(spydf['date'], spydf['close'])
plt.scatter(spydf[(spydf['signal'] == 1)]['buy_date'], spydf[(spydf['signal'] == 1)]['close'], label = 'Buy', marker='^', c='g')
plt.scatter(spydf[(spydf['signal'] == -1)]['sell_date'], spydf[(spydf['signal'] == -1)]['close'], label = 'Sell', marker='v', c='r')

plt.title('Price Chart & Historical Trades', fontweight="bold")
plt.legend()
plt.show()
